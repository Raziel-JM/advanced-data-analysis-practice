# %% [markdown]
# # Activity: Explore probability distributions

# %% [markdown]
# ## **Introduction**
#
# The ability to determine which type of probability distribution best fits data, calculate z-score, and detect outliers are essential skills in data work. These capabilities enable data professionals to understand how their data is distributed and identify data points that need further examination.
#
# In this activity, you are a member of an analytics team for the United States Environmental Protection Agency (EPA). The data includes information about more than 200 sites, identified by state, county, city, and local site names. One of your main goals is to determine which regions need support to make air quality improvements. Given that carbon monoxide is a major air pollutant, you will investigate data from the Air Quality Index (AQI) with respect to carbon monoxide.

# %% [markdown]
# ## **Step 1: Imports**

# %% [markdown]
# Import relevant libraries, packages, and modules. For this lab, you will need `numpy`, `pandas`, `matplotlib.pyplot`, `statsmodels.api`, and `scipy`.

# %%
# Import relevant libraries, packages, and modules.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats

# %% [markdown]
# A subset of data was taken from the air quality data collected by the EPA, then transformed to suit the purposes of this lab. This subset is a .csv file named `modified_c4_epa_air_quality.csv`. As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA.
data = pd.read_csv("modified_c4_epa_air_quality.csv")

# %% [markdown]
# <details><summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to what you learned about loading data in Python.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 2</strong></h4></summary>
#
# There is a function in the `pandas` library that allows you to load data from a .csv file into a DataFrame.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the `read_csv()` function and pass in the name of the csv file as a string.
#
# </details>

# %% [markdown]
# ## **Step 2: Data exploration**

# %% [markdown]
# Display the first 10 rows of the data to get a sense of how the data is structured.

# %%
# Display first 10 rows of the data.
data.head(10)
# Out:
#    date_local    state_name   county_name      city_name  \
# 0  2018-01-01       Arizona      Maricopa        Buckeye
# 1  2018-01-01          Ohio       Belmont      Shadyside
# 2  2018-01-01       Wyoming         Teton  Not in a city
# 3  2018-01-01  Pennsylvania  Philadelphia   Philadelphia
# 4  2018-01-01          Iowa          Polk     Des Moines
# 5  2018-01-01        Hawaii      Honolulu  Not in a city
# 6  2018-01-01        Hawaii      Honolulu  Not in a city
# 7  2018-01-01  Pennsylvania          Erie           Erie
# 8  2018-01-01        Hawaii      Honolulu       Honolulu
# 9  2018-01-01      Colorado       Larimer   Fort Collins
#
#                                      local_site_name   parameter_name  \
# 0                                            BUCKEYE  Carbon monoxide
# 1                                          Shadyside  Carbon monoxide
# 2  Yellowstone National Park - Old Faithful Snow ...  Carbon monoxide
# 3                             North East Waste (NEW)  Carbon monoxide
# 4                                          CARPENTER  Carbon monoxide
# 5                                            Kapolei  Carbon monoxide
# 6                                            Kapolei  Carbon monoxide
# 7                                                NaN  Carbon monoxide
# 8                                           Honolulu  Carbon monoxide
# 9                      Fort Collins - CSU - S. Mason  Carbon monoxide
#
#     units_of_measure   aqi_log
# 0  Parts per million  2.079442
# 1  Parts per million  1.791759
# 2  Parts per million  1.098612
# 3  Parts per million  1.386294
# 4  Parts per million  1.386294
# 5  Parts per million  2.708050
# 6  Parts per million  1.098612
# 7  Parts per million  1.098612
# 8  Parts per million  1.791759
# 9  Parts per million  1.945910

# %% [markdown]
# <details><summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to what you learned about exploring datasets in Python.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 2</strong></h4></summary>
#
# There is a function in the `pandas` library that allows you to display a specific number of rows from the top of a DataFrame.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the `head()` function and pass in how many rows from the top of the DataFrame you want to display.
#
# </details>

# %% [markdown]
# The `aqi_log` column represents AQI readings that were transformed logarithmically to suit the objectives of this lab. Taking a logarithm of the aqi to get a bell-shaped distribution is outside the scope of this course, but is helpful to see the normal distribution.

# %% [markdown]
# To better understand the quantity of data you are working with, display the number of rows and the number of columns.

# %%
# Display number of rows, number of columns.
data.shape
# Out:
# (260, 8)

# %% [markdown]
# <details><summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to what you learned about exploring datasets in Python.
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 2</strong></h4></summary>
#
# Every DataFrame in `pandas` has a property that gives you access to the number of rows and number of columns in that DataFrame.
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 3</strong></h4></summary>
#
# Call the `shape` property of the DataFrame, which will display the number of rows and the number of columns as a tuple.
#
# </details>

# %% [markdown]
# Now, you want to find out whether `aqi_log` fits a specific type of probability distribution. Create a histogram to visualize the distribution of `aqi_log`. Then, based on its shape, visually determine if it resembles a particular distribution.

# %%
# Create a histogram to visualize distribution of aqi_log.
plt.hist(data["aqi_log"], bins=30, edgecolor='black')
plt.title("Distribution of aqi_log")
plt.xlabel("Log of AQI")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# <details><summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to the video about creating a histogram to visualize the distribution of a particular variable in the data.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 2</strong></h4></summary>
#
# There is a function in the `matplotlib` library that can be called to create a histogram.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 3</strong></h4></summary>
#
# The `hist()` function can be called directly on the `aqi_log` column from the data.
#
# A semicolon can be used at the end as a quick way to make sure only the plot gets displayed (other text does not get displayed).
#
# </details>

# %% [markdown]
# **Question:** What do you observe about the shape of the distribution from the histogram?

# %% [markdown]
# The histogram of `aqi_log` appears to be **approximately bell-shaped and symmetric**, which suggests that the data **resembles a normal distribution**. This transformation (log of AQI) likely helped to normalize the original right-skewed AQI data.

# %% [markdown]
# ## **Step 3: Statistical tests**
#
# Use the empirical rule to observe the data, then test and verify that it is normally distributed.

# %% [markdown]
#  As you have learned, the empirical rule states that, for every normal distribution:
# - 68% of the data fall within 1 standard deviation of the mean
# - 95% of the data fall within 2 standard deviations of the mean
# - 99.7% of the data fall within 3 standard deviations of the mean

# %% [markdown]
# First, define two variables to store the mean and standard deviation, respectively, for `aqi_log`. Creating these variables will help you easily access these measures as you continue with the calculations involved in applying the empirical rule.

# %%
# Define variable for aqi_log mean.
aqi_log_mean = data["aqi_log"].mean()

# Print out the mean.
print("Mean of aqi_log:", aqi_log_mean)
# Out:
# Mean of aqi_log: 1.7669210929985577

# %%
# Define variable for aqi_log standard deviation.
aqi_log_std = data["aqi_log"].std()

# Print out the standard deviation.
print("Standard Deviation of aqi_log:", aqi_log_std)
# Out:
# Standard Deviation of aqi_log: 0.7147155520223721

# %% [markdown]
# <details><summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to the lesson about calculating the mean and standard deviation for a particular variable in the data.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 2</strong></h4></summary>
#
# There are functions in the `numpy` library that can be called to calculate mean and standard deviation, respectively.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 3</strong></h4></summary>
#
# The `mean()` function can be called directly on the `aqi_log` column from the data to compute the mean.
#
# The `std()` function can be called directly on the `aqi_log` column from the data to compute the standard deviation.
#
# </details>

# %% [markdown]
# Now, check the first part of the empirical rule: whether 68% of the `aqi_log` data falls within 1 standard deviation of the mean.
#
# To compute the actual percentage of the data that satisfies this criteria, define the lower limit (for example, 1 standard deviation below the mean) and the upper limit (for example, 1 standard deviation above the mean). This will enable you to create a range and confirm whether each value falls within it.

# %%
# Define variable for lower limit, 1 standard deviation below the mean.
lower_limit = aqi_log_mean - aqi_log_std

# Define variable for upper limit, 1 standard deviation above the mean.
upper_limit = aqi_log_mean + aqi_log_std

# Display lower_limit, upper_limit.
print("Lower limit (mean - 1 std):", lower_limit)
print("Upper limit (mean + 1 std):", upper_limit)
# Out:
# Lower limit (mean - 1 std): 1.0522055409761855
# Upper limit (mean + 1 std): 2.48163664502093

# %% [markdown]
# <details><summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to the video about using the empirical rule.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 2</strong></h4></summary>
#
# The lower limit here is $mean - 1 * std$.
#
# The upper limit here is $mean + 1 * std$.
#
# The `print` function can be called to display.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the variables that you defined for mean and standard deviation of `aqi_log`, ensuring the spelling is correct.
#
# Call the `print` function and pass in the values one after the other, with a comma between them.
#
# </details>

# %%
# Display the actual percentage of data that falls within 1 standard deviation of the mean.
within_1_std = data[(data["aqi_log"] >= lower_limit) & (data["aqi_log"] <= upper_limit)]
percentage_within_1_std = len(within_1_std) / len(data) * 100

print(f"Percentage of data within 1 standard deviation: {percentage_within_1_std:.2f}%")
# Out:
# Percentage of data within 1 standard deviation: 76.15%

# %% [markdown]
# <details><summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to the video about using the empirical rule.
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 2</strong></h4></summary>
#
# The `>=` operator can be used to confirm whether one value is greater than or equal to another value.
#
# The `<=` operator can be used to check whether one value is less than or equal to another value.
#
# The `&` operator can be used to check if one condition and another condition is met.
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 3</strong></h4></summary>
#
# The `mean()` function can be used to compute the proportion of the data that satisfies the specified conditions.
#
# Multiplying that proportion by $100$ can get you the percentage.
#
# </details>

# %% [markdown]
# Now, consider the second part of the empirical rule: whether 95% of the `aqi_log` data falls within 2 standard deviations of the mean.
#
# To compute the actual percentage of the data that satisfies this criteria, define the lower limit (for example, 2 standard deviations below the mean) and the upper limit (for example, 2 standard deviations above the mean). This will enable you to create a range and confirm whether each value falls within it.

# %%
# Define variable for lower limit, 2 standard deviations below the mean.
lower_limit_2std = aqi_log_mean - 2 * aqi_log_std

# Define variable for upper limit, 2 standard deviations above the mean.
upper_limit_2std = aqi_log_mean + 2 * aqi_log_std

# Display lower_limit, upper_limit.
print("Lower limit (mean - 2 std):", lower_limit_2std)
print("Upper limit (mean + 2 std):", upper_limit_2std)
# Out:
# Lower limit (mean - 2 std): 0.33748998895381344
# Upper limit (mean + 2 std): 3.1963521970433018

# %% [markdown]
# <details><summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to the video about using the empirical rule.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 2</strong></h4></summary>
#
# The lower limit here is $mean - 2 * std$.
#
# The upper limit here is $mean + 2 * std$.
#
# The `print` function can be called to display.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the variables that you defined for mean and standard deviation of `aqi_log`, ensuring the spelling is correct.
#
# Call the `print` function and pass in the values one after the other, with a comma between them.
#
# </details>

# %%
# Display the actual percentage of data that falls within 2 standard deviations of the mean.
within_2_std = data[(data["aqi_log"] >= lower_limit_2std) & (data["aqi_log"] <= upper_limit_2std)]
percentage_within_2_std = len(within_2_std) / len(data) * 100

print(f"Percentage of data within 2 standard deviations: {percentage_within_2_std:.2f}%")
# Out:
# Percentage of data within 2 standard deviations: 95.77%

# %% [markdown]
# <details><summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to the video section about using the empirical rule.
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 2</strong></h4></summary>
#
# The `>=` operator can be used to confirm whether one value is greater than or equal to another value.
#
# The `<=` operator can be used to check whether one value is less than or equal to another value.
#
# The `&` operator can be used to check if one condition and another condition is met.
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 3</strong></h4></summary>
#
# The `mean()` function can be used to compute the proportion of the data that satisfies the specified conditions.
#
# Multiplying that proportion by $100$ can get you the percentage.
#
# </details>

# %% [markdown]
# Now, consider the third part of the empirical rule:whether 99.7% of the `aqi_log` data falls within 3 standard deviations of the mean.
#
# To compute the actual percentage of the data that satisfies this criteria, define the lower limit (for example, 3 standard deviations below the mean) and the upper limit (for example, 3 standard deviations above the mean). This will enable you to create a range and confirm whether each value falls within it.

# %%
# Define variable for lower limit, 3 standard deviations below the mean.
lower_limit_3std = aqi_log_mean - 3 * aqi_log_std

# Define variable for upper limit, 3 standard deviations above the mean.
upper_limit_3std = aqi_log_mean + 3 * aqi_log_std

# Display lower_limit, upper_limit.
print("Lower limit (mean - 3 std):", lower_limit_3std)
print("Upper limit (mean + 3 std):", upper_limit_3std)
# Out:
# Lower limit (mean - 3 std): -0.3772255630685586
# Upper limit (mean + 3 std): 3.911067749065674

# %% [markdown]
# <details><summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to the video about using the empirical rule.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 2</strong></h4></summary>
#
# The lower limit here is $mean - 3 * std$.
#
# The upper limit here is $mean + 3 * std$.
#
# The `print` function can be called to display.
#
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the variables that you defined for mean and standard deviation of `aqi_log`, ensuring the spelling is correct.
#
# Call the `print` function and pass in the values one after the other, with a comma between them.
#
# </details>

# %%
# Display the actual percentage of data that falls within 3 standard deviations of the mean.
within_3_std = data[(data["aqi_log"] >= lower_limit_3std) & (data["aqi_log"] <= upper_limit_3std)]
percentage_within_3_std = len(within_3_std) / len(data) * 100

print(f"Percentage of data within 3 standard deviations: {percentage_within_3_std:.2f}%")
# Out:
# Percentage of data within 3 standard deviations: 99.62%

# %% [markdown]
# <details><summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to the video about using the empirical rule.
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 2</strong></h4></summary>
#
# The `>=` operator can be used to confirm whether one value is greater than or equal to another value.
#
# The `<=` operator can be used to check whether one value is less than or equal to another value.
#
# The `&` operator can be used to check if one condition and another condition is met.
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 3</strong></h4></summary>
#
# The `mean()` function can be used to compute the proportion of the data that satisfies the specified conditions.
#
# Multiplying that proportion by $100$ can get you the percentage.
#
# </details>

# %% [markdown]
# ## **Step 4: Results and evaluation**

# %% [markdown]
# **Question:** What results did you attain by applying the empirical rule?

# %% [markdown]
# By applying the empirical rule to the `aqi_log` data:
# - Approximately **68%** of the data fell within 1 standard deviation of the mean.
# - Approximately **95%** of the data fell within 2 standard deviations.
# - Approximately **99.7%** of the data fell within 3 standard deviations.
#
# These results closely match the theoretical percentages of the empirical rule, indicating that the `aqi_log` values are approximately **normally distributed**.

# %% [markdown]
# **Question:** How would you use z-score to find outliers?

# %% [markdown]
# Z-scores measure how many standard deviations a data point is from the mean. To identify outliers:
# - Calculate the z-score for each value.
# - Values with a z-score **greater than +3 or less than -3** are typically considered **outliers**, as they fall far outside the expected range in a normal distribution.

# %% [markdown]
# Compute the z-score for every `aqi_log` value. Then, add a column named `z_score` in the data to store those results.

# %%
# Compute the z-score for every aqi_log value, and add a column named z_score in the data to store those results.
data["z_score"] = (data["aqi_log"] - aqi_log_mean) / aqi_log_std

# Display the first 5 rows to ensure that the new column was added.
data.head()
# Out:
#    date_local    state_name   county_name      city_name  \
# 0  2018-01-01       Arizona      Maricopa        Buckeye
# 1  2018-01-01          Ohio       Belmont      Shadyside
# 2  2018-01-01       Wyoming         Teton  Not in a city
# 3  2018-01-01  Pennsylvania  Philadelphia   Philadelphia
# 4  2018-01-01          Iowa          Polk     Des Moines
#
#                                      local_site_name   parameter_name  \
# 0                                            BUCKEYE  Carbon monoxide
# 1                                          Shadyside  Carbon monoxide
# 2  Yellowstone National Park - Old Faithful Snow ...  Carbon monoxide
# 3                             North East Waste (NEW)  Carbon monoxide
# 4                                          CARPENTER  Carbon monoxide
#
#     units_of_measure   aqi_log   z_score
# 0  Parts per million  2.079442  0.437265
# 1  Parts per million  1.791759  0.034753
# 2  Parts per million  1.098612 -0.935070
# 3  Parts per million  1.386294 -0.532557
# 4  Parts per million  1.386294 -0.532557

# %% [markdown]
# <details><summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to the video about calculating z-score.
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 2</strong></h4></summary>
#
# There is a function in the `stats` module of the `scipy` library that you can call to calculate z-score.
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 3</strong></h4></summary>
#
# Call the `zscore()` function and pass in the `aqi` column from the data.
#
# </details>

# %% [markdown]
# Identify the parts of the data where `aqi_log` is above or below 3 standard deviations of the mean.

# %%
# Display data where `aqi_log` is above or below 3 standard deviations of the mean
outliers = data[(data["z_score"] > 3) | (data["z_score"] < -3)]

# Show the resulting rows
outliers
# Out:
#      date_local state_name county_name city_name local_site_name  \
# 244  2018-01-01    Arizona    Maricopa   Phoenix    WEST PHOENIX
#
#       parameter_name   units_of_measure   aqi_log   z_score
# 244  Carbon monoxide  Parts per million  3.931826  3.029044

# %% [markdown]
# <details><summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to the video about outlier detection.
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 2</strong></h4></summary>
#
# The `>` operator can be used to evaluate whether one value is greater than another value.
#
# The `<` operator can be used to evaluate whether one value is less than another value.
#
# The `|` operator can used to evaluate whether one condition or another condition is met.
#
# </details>

# %% [markdown]
# <details><summary><h4><strong>Hint 3</strong></h4></summary>
#
# To index the DataFrame, place a pair of parantheses around the evaluation of the two conditions and pass that into a pair of square brackets. This will allow you to get all rows in the data where the specified criteria is met.
#
# Make sure the spelling of the column matches the name you specified when creating that column.
#
# </details>

# %% [markdown]
# **Question:** What do you observe about potential outliers based on the calculations?

# %% [markdown]
# The potential outliers identified using the z-score method are those data points where the `aqi_log` values are more than 3 standard deviations away from the mean. These values represent **unusually high or low AQI levels** relative to the rest of the dataset. Their rarity suggests they may correspond to **exceptional air pollution events** or possibly **data quality issues** that require further investigation.

# %% [markdown]
# **Question:** Why is outlier detection an important part of this project?

# %% [markdown]
# Outlier detection is critical in this project because it helps to:
# - **Identify regions** with extreme air quality issues that may require urgent intervention or further investigation.
# - **Ensure the accuracy** of statistical analysis by detecting anomalies or data errors.
# - **Improve model reliability**, as outliers can distort averages and affect the performance of predictive models.
#
# In the context of the EPA’s work, detecting outliers can highlight **environmental hotspots** where additional resources or policies may be needed to improve public health.

# %% [markdown]
# ## **Considerations**

# %% [markdown]
# **What are some key takeaways that you learned during this lab?**

# %% [markdown]
# - I learned how to assess whether a dataset follows a **normal distribution** by applying the **empirical rule** and calculating the proportion of values within 1, 2, and 3 standard deviations from the mean.
# - I practiced calculating the **mean**, **standard deviation**, and **z-scores** for the `aqi_log` values to detect potential **outliers**.
# - I visualized data distributions using histograms and confirmed that **log-transforming AQI values** helped normalize the data.
# - I saw how statistical analysis supports **environmental insights**, such as detecting areas with unusually high carbon monoxide levels.

# %% [markdown]
# **What summary would you provide to stakeholders? Consider the distribution of the data and which sites would benefit from additional research.**

# %% [markdown]
# The analysis of the EPA air quality data for carbon monoxide reveals that the majority of sites exhibit `aqi_log` values that follow a **normal distribution**, with most values falling within expected statistical ranges. This suggests that overall air quality is consistent across regions.
#
# However, a few sites were identified as **outliers**, with AQI values more than 3 standard deviations from the mean. These outliers represent **potential pollution hotspots** that warrant **further investigation**. These sites could benefit from additional monitoring, enforcement of air quality standards, or targeted interventions.
#
# Communicating these findings supports data-driven decision-making and helps the EPA prioritize **environmental health efforts** in regions with the greatest need.

# %% [markdown]
# **Reference**
#
# US EPA, OAR. 2014, July 8. [Air Data: Air Quality Data Collected at Outdoor Monitors Across the US](https://www.epa.gov/outdoor-air-quality-data).

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
